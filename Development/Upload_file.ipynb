-- %% [markdown]
-- Create DB

-- %%
create database dev_1.data

-- %%
create volume dev_1.data.files

-- %% [markdown]
-- ## Dataframe Practice

-- %%
%python
df = spark.read.csv("/Volumes/dev_1/data/files/Management_data/project_managment_file.csv")

-- %%
%python
df.show()

-- %%
%python
display(df)

-- %%
%python
df = spark.read.csv("/Volumes/dev_1/data/files/Management_data/project_managment_file.csv",header=True)
display (df)

-- %%
%python
df.printSchema()

-- %%
%python
df = spark.read.csv("/Volumes/dev_1/data/files/Management_data/project_managment_file.csv",header=True,inferSchema=True)

-- %%
%python
df.printSchema()
       
df.show()
