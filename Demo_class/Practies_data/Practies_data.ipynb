-- %%
CREATE CATALOG demo_db

-- %%
use catalog demo_db

-- %%
create schema dbdemo

-- %%
create table dbdemo.empinfo(
  Name_employee string,
  Joining_Date string,
  Email_Address string,
  Department string,
  Monthly_Salary int

)

-- %%
select * from dbdemo.empinfo

-- %%
insert into dbdemo.empinfo values(
'Mark',	'44561',	'Mark@demomail.com',	'Human Resources',	'5830',
'Brian',	'44561',	'Brian@demomail.com',	'Sales',	'3450',
'Alan',	'44575',	'Alan@demomail.com',	'Legal',	'5831')

-- %%
use schema dbdemo

-- %%
select * from empinfo

-- %%
insert into dbdemo.empinfo values('Mark',	44561,	'Mark@demomail.com',	'Human Resources',5830),
('Brian',	44562,	'Brian@demomail.com',	'Sales',	3450),
('Alan',	44575,	'Alan@demomail.com',	'Legal',	5831)

-- %%
SELECT * FROM dbdemo.empinfo

-- %%
CREATE TABLE dbdemo.salary_structure(
  department string,
  salary int
)

-- %%
insert into dbdemo.salary_structure values('Human Resources',	'5830'),
('Sales',	'3450'),
('Legal',	'5831'),
('Retail',	'2785'),
('Sales',	'5832'),
('Accounting',	'3125'),
('Accounting',	'5833')

-- %%
select * from dbdemo.salary_structure

-- %%
show dbdemo

-- %%
use schema dbdemo

-- %%
select * from empinfo

-- %%
select * from dbdemo.salary_structure

-- %%
use catalog demo_db

-- %%
select * from dbdemo.empinfo

-- %%
select * from dbdemo.salary_structure

-- %%
select e.Department,s.salary from dbdemo.empinfo e left join dbdemo.salary_structure s on s.salary = e.Department

-- %%
SELECT try_cast(Department AS BIGINT) AS dept_id
FROM empinfo;

-- %%
use catalog demo_db

-- %%
select * from dbdemo.empinfo

-- %%
use catalog demo_db

-- %%
use dbdemo

-- %%
SELECT * FROM empinfo

-- %%
SELECT * FROM dbdemo.salary_structure

-- %%
delete from dbdemo.salary_structure where department = 'Accounting'

-- %%
select * from dbdemo.salary_structure

-- %%
select distinct * from dbdemo.salary_structure
